# %%
from qmlab.preprocessing import parse_biomed_data_to_ndarray, reduce_feature_dim, scale_data_to_specified_range
from sklearn.model_selection import train_test_split
from qmlab.plotting import plot_3d_data_with_train_test_split
random_state = 12345

X, y = parse_biomed_data_to_ndarray("haberman_new")

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=random_state)
# %matplotlib inline

# %%
print(X_train.shape)
plot_3d_data_with_train_test_split(X_train, y_train, X_test, y_test)
# Out:
# (229, 3)
